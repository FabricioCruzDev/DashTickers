# %%
# !pip install yfinance --upgrade --no-cache-dir

# %%
import pandas as pd
import yfinance as yf

# %%
df_itau = yf.Ticker('ITUB4.SA')

# %%
df_itau.dividends
# Out:
# Date
# 2010-05-03 00:00:00-03:00    0.005464
# 2010-06-01 00:00:00-03:00    0.005464
# 2010-07-01 00:00:00-03:00    0.005464
# 2010-08-02 00:00:00-03:00    0.005464
# 2010-08-11 00:00:00-03:00    0.095406
#                                ...
# 2024-03-01 00:00:00-03:00    0.017650
# 2024-03-22 00:00:00-03:00    0.241800
# 2024-04-01 00:00:00-03:00    0.017650
# 2024-05-02 00:00:00-03:00    0.017650
# 2024-06-03 00:00:00-03:00    0.017650
# Name: Dividends, Length: 214, dtype: float64

# %%
df_itau.history(period = 'max')
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-12-21 00:00:00-02:00   1.562144   1.658147   1.561961   1.642622
# 2000-12-22 00:00:00-02:00   1.626086   1.626086   1.561777   1.571424
# 2000-12-25 00:00:00-02:00   1.571424   1.571424   1.571424   1.571424
# 2000-12-26 00:00:00-02:00   1.562788   1.572801   1.547997   1.570964
# 2000-12-27 00:00:00-02:00   1.598524   1.624248   1.570964   1.624248
# ...                              ...        ...        ...        ...
# 2024-06-03 00:00:00-03:00  31.160000  31.650000  31.090000  31.450001
# 2024-06-04 00:00:00-03:00  31.340000  31.670000  31.170000  31.559999
# 2024-06-05 00:00:00-03:00  31.450001  31.639999  31.330000  31.500000
# 2024-06-06 00:00:00-03:00  31.510000  32.000000  31.459999  31.900000
# 2024-06-07 00:00:00-03:00  31.580000  31.799999  31.330000  31.450001
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
df = yf.download(['ITUB3.SA', 'AMER3.SA', 'BBAS3.SA', 'CMIG4.SA', 'CXSE3.SA', 'GOAU4.SA', 'ITSA4.SA', 'RAIZ4.SA', 'TRPL4.SA', 'VALE3.SA'], period = 'max', group_by= 'tickers')
# Out:
# [*********************100%%**********************]  10 of 10 completed

# %%
df = df.stack(level=0).rename_axis(['Date', 'Ticker']).reset_index(level=1)

# %%
df.head()
# Out:
# Price         Ticker    Adj Close         Close          High           Low  \
# Date
# 2000-01-03  BBAS3.SA     0.531419      1.366666      1.426666      1.366666
# 2000-01-03  CMIG4.SA  2903.688477  10500.434570  10977.481445  10326.963867
# 2000-01-03  GOAU4.SA   142.199341    870.000000    879.900024    860.000000
# 2000-01-03  ITSA4.SA     0.407176      0.889823      0.939010      0.831694
# 2000-01-03  ITUB3.SA     1.127366      2.318106      2.318106      2.318106
#
# Price               Open      Volume
# Date
# 2000-01-03      1.400000   1029600.0
# 2000-01-03  10977.481445   1172481.0
# 2000-01-03    870.000000    150000.0
# 2000-01-03      0.836166  12526017.0
# 2000-01-03      2.318106     65225.0

# %%
df.to_csv('df_tickers.csv')
